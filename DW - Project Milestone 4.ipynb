# %% [markdown]
# **Title**: Project Milestone 4
# **Author**: Ryan Weeks
# **Date**: 2/15/2025
# **Description**: I will collect and perform at least 5 data transformation/cleansing steps to my html/website data.

# %%
import pandas as pd
import requests
from io import StringIO

def construct_url(position, year):
    """Construct URL based on the player's position and year."""
    base_url = "https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/{year}/player/"
    if position == 'QB':
        return base_url.format(year=year) + "passing.csv"
    elif position == 'RB':
        return base_url.format(year=year) + "rushing.csv"
    elif position in ['WR', 'TE']:
        return base_url.format(year=year) + "receiving.csv"
    elif position == 'K':
        return base_url.format(year=year) + "field-goals.csv"
    return None

def scrape_data(player_name, position, start_year, end_year):
    """Scrape data for each player and year."""
    scraped_data = []
    
    for year in range(int(start_year), int(end_year) + 1):
        url = construct_url(position, year)
        if url:
            print(f"Scraping data for {player_name} ({position}) from year {year} at {url}")
            try:
                response = requests.get(url)
                
                if response.status_code == 200:
                    # Use StringIO to read the content as if it were a file
                    csv_data = StringIO(response.text)
                    
                    try:
                        # Try reading the CSV with a comma delimiter
                        df = pd.read_csv(csv_data, delimiter=',')
                        scraped_data.append({'player': player_name, 'position': position, 'year': year, 'data': df})
                        print(f"Data for {player_name} ({position}) in {year} successfully scraped.")
                    except pd.errors.ParserError:
                        # If comma delimiter fails, try reading with a semicolon
                        df = pd.read_csv(csv_data, delimiter=';')
                        scraped_data.append({'player': player_name, 'position': position, 'year': year, 'data': df})
                        print(f"Data for {player_name} ({position}) in {year} scraped with semicolon delimiter.")
                else:
                    print(f"Failed to retrieve data for {player_name} ({position}) from year {year} at {url}")
            except Exception as e:
                print(f"Error scraping data for {player_name} ({position}) from year {year}: {e}")
    
    return scraped_data

# Example usage:
hof_df = pd.read_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\hof_df_filtered.csv")
for index, row in hof_df.iterrows():
    player_name = row['player']
    position = row['position']
    start_year = row['from']
    end_year = row['to']
    
    scraped_data = scrape_data(player_name, position, start_year, end_year)
    
    # You can now process or save scraped_data for the current player here
# Out:
# Scraping data for Calvin Johnson (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Calvin Johnson (WR) in 2007 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Calvin Johnson (WR) in 2008 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Calvin Johnson (WR) in 2009 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Calvin Johnson (WR) in 2010 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/receiving.csv
# Data for Calvin Johnson (WR) in 2011 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/receiving.csv
# Data for Calvin Johnson (WR) in 2012 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2013 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2013/player/receiving.csv
# Data for Calvin Johnson (WR) in 2013 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2014 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2014/player/receiving.csv
# Data for Calvin Johnson (WR) in 2014 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2015 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2015/player/receiving.csv
# Data for Calvin Johnson (WR) in 2015 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/passing.csv
# Data for Peyton Manning (QB) in 1998 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/passing.csv
# Data for Peyton Manning (QB) in 1999 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/passing.csv
# Data for Peyton Manning (QB) in 2000 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/passing.csv
# Data for Peyton Manning (QB) in 2001 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/passing.csv
# Data for Peyton Manning (QB) in 2002 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/passing.csv
# Data for Peyton Manning (QB) in 2003 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/passing.csv
# Data for Peyton Manning (QB) in 2004 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/passing.csv
# Data for Peyton Manning (QB) in 2005 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/passing.csv
# Data for Peyton Manning (QB) in 2006 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/passing.csv
# Data for Peyton Manning (QB) in 2007 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/passing.csv
# Data for Peyton Manning (QB) in 2008 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/passing.csv
# Data for Peyton Manning (QB) in 2009 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/passing.csv
# Data for Peyton Manning (QB) in 2010 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/passing.csv
# Data for Peyton Manning (QB) in 2011 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/passing.csv
# Data for Peyton Manning (QB) in 2012 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2013 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2013/player/passing.csv
# Data for Peyton Manning (QB) in 2013 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2014 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2014/player/passing.csv
# Data for Peyton Manning (QB) in 2014 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2015 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2015/player/passing.csv
# Data for Peyton Manning (QB) in 2015 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/receiving.csv
# Data for Isaac Bruce (WR) in 1994 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/receiving.csv
# Data for Isaac Bruce (WR) in 1995 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Isaac Bruce (WR) in 1996 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Isaac Bruce (WR) in 1997 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Isaac Bruce (WR) in 1998 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Isaac Bruce (WR) in 1999 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Isaac Bruce (WR) in 2000 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Isaac Bruce (WR) in 2001 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Isaac Bruce (WR) in 2002 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Isaac Bruce (WR) in 2003 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Isaac Bruce (WR) in 2004 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Isaac Bruce (WR) in 2005 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Isaac Bruce (WR) in 2006 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Isaac Bruce (WR) in 2007 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Isaac Bruce (WR) in 2008 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Isaac Bruce (WR) in 2009 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/rushing.csv
# Data for Edgerrin James (RB) in 1999 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/rushing.csv
# Data for Edgerrin James (RB) in 2000 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for Edgerrin James (RB) in 2001 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/rushing.csv
# Data for Edgerrin James (RB) in 2002 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/rushing.csv
# Data for Edgerrin James (RB) in 2003 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/rushing.csv
# Data for Edgerrin James (RB) in 2004 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/rushing.csv
# Data for Edgerrin James (RB) in 2005 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/rushing.csv
# Data for Edgerrin James (RB) in 2006 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/rushing.csv
# Data for Edgerrin James (RB) in 2007 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/rushing.csv
# Data for Edgerrin James (RB) in 2008 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/rushing.csv
# Data for Edgerrin James (RB) in 2009 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Tony Gonzalez (TE) in 1997 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Tony Gonzalez (TE) in 1998 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Tony Gonzalez (TE) in 1999 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2000 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2001 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2002 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2003 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2004 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2005 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2006 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2007 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2008 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2009 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2010 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2011 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2012 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2013 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2013/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2013 successfully scraped.
# Scraping data for Randy Moss (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Randy Moss (WR) in 1998 successfully scraped.
# Scraping data for Randy Moss (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Randy Moss (WR) in 1999 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Randy Moss (WR) in 2000 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Randy Moss (WR) in 2001 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Randy Moss (WR) in 2002 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Randy Moss (WR) in 2003 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Randy Moss (WR) in 2004 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Randy Moss (WR) in 2005 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Randy Moss (WR) in 2006 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Randy Moss (WR) in 2007 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Randy Moss (WR) in 2008 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Randy Moss (WR) in 2009 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Randy Moss (WR) in 2010 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/receiving.csv
# Data for Randy Moss (WR) in 2011 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/receiving.csv
# Data for Randy Moss (WR) in 2012 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Terrell Owens (WR) in 1996 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Terrell Owens (WR) in 1997 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Terrell Owens (WR) in 1998 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Terrell Owens (WR) in 1999 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Terrell Owens (WR) in 2000 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Terrell Owens (WR) in 2001 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Terrell Owens (WR) in 2002 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Terrell Owens (WR) in 2003 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Terrell Owens (WR) in 2004 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Terrell Owens (WR) in 2005 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Terrell Owens (WR) in 2006 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Terrell Owens (WR) in 2007 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Terrell Owens (WR) in 2008 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Terrell Owens (WR) in 2009 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Terrell Owens (WR) in 2010 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/field-goals.csv
# Data for Morten Andersen (K) in 1982 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/field-goals.csv
# Data for Morten Andersen (K) in 1983 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/field-goals.csv
# Data for Morten Andersen (K) in 1984 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/field-goals.csv
# Data for Morten Andersen (K) in 1985 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/field-goals.csv
# Data for Morten Andersen (K) in 1986 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/field-goals.csv
# Data for Morten Andersen (K) in 1987 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/field-goals.csv
# Data for Morten Andersen (K) in 1988 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/field-goals.csv
# Data for Morten Andersen (K) in 1989 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/field-goals.csv
# Data for Morten Andersen (K) in 1990 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/field-goals.csv
# Data for Morten Andersen (K) in 1991 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/field-goals.csv
# Data for Morten Andersen (K) in 1992 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/field-goals.csv
# Data for Morten Andersen (K) in 1993 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/field-goals.csv
# Data for Morten Andersen (K) in 1994 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/field-goals.csv
# Data for Morten Andersen (K) in 1995 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/field-goals.csv
# Data for Morten Andersen (K) in 1996 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/field-goals.csv
# Data for Morten Andersen (K) in 1997 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/field-goals.csv
# Data for Morten Andersen (K) in 1998 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/field-goals.csv
# Data for Morten Andersen (K) in 1999 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/field-goals.csv
# Data for Morten Andersen (K) in 2000 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/field-goals.csv
# Data for Morten Andersen (K) in 2001 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/field-goals.csv
# Data for Morten Andersen (K) in 2002 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/field-goals.csv
# Data for Morten Andersen (K) in 2003 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/field-goals.csv
# Data for Morten Andersen (K) in 2004 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/field-goals.csv
# Data for Morten Andersen (K) in 2005 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/field-goals.csv
# Data for Morten Andersen (K) in 2006 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/field-goals.csv
# Data for Morten Andersen (K) in 2007 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Terrell Davis (RB) in 1995 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Terrell Davis (RB) in 1996 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Terrell Davis (RB) in 1997 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/rushing.csv
# Data for Terrell Davis (RB) in 1998 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/rushing.csv
# Data for Terrell Davis (RB) in 1999 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/rushing.csv
# Data for Terrell Davis (RB) in 2000 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for Terrell Davis (RB) in 2001 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2001 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2002 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2003 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2004 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2005 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2006 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2007 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2008 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2009 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2010 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2011 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/passing.csv
# Data for Kurt Warner (QB) in 1998 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/passing.csv
# Data for Kurt Warner (QB) in 1999 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/passing.csv
# Data for Kurt Warner (QB) in 2000 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/passing.csv
# Data for Kurt Warner (QB) in 2001 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/passing.csv
# Data for Kurt Warner (QB) in 2002 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/passing.csv
# Data for Kurt Warner (QB) in 2003 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/passing.csv
# Data for Kurt Warner (QB) in 2004 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/passing.csv
# Data for Kurt Warner (QB) in 2005 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/passing.csv
# Data for Kurt Warner (QB) in 2006 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/passing.csv
# Data for Kurt Warner (QB) in 2007 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/passing.csv
# Data for Kurt Warner (QB) in 2008 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/passing.csv
# Data for Kurt Warner (QB) in 2009 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/passing.csv
# Data for Brett Favre (QB) in 1991 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/passing.csv
# Data for Brett Favre (QB) in 1992 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/passing.csv
# Data for Brett Favre (QB) in 1993 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/passing.csv
# Data for Brett Favre (QB) in 1994 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/passing.csv
# Data for Brett Favre (QB) in 1995 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/passing.csv
# Data for Brett Favre (QB) in 1996 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/passing.csv
# Data for Brett Favre (QB) in 1997 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/passing.csv
# Data for Brett Favre (QB) in 1998 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/passing.csv
# Data for Brett Favre (QB) in 1999 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/passing.csv
# Data for Brett Favre (QB) in 2000 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/passing.csv
# Data for Brett Favre (QB) in 2001 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/passing.csv
# Data for Brett Favre (QB) in 2002 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/passing.csv
# Data for Brett Favre (QB) in 2003 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/passing.csv
# Data for Brett Favre (QB) in 2004 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/passing.csv
# Data for Brett Favre (QB) in 2005 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/passing.csv
# Data for Brett Favre (QB) in 2006 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/passing.csv
# Data for Brett Favre (QB) in 2007 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/passing.csv
# Data for Brett Favre (QB) in 2008 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/passing.csv
# Data for Brett Favre (QB) in 2009 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/passing.csv
# Data for Brett Favre (QB) in 2010 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Marvin Harrison (WR) in 1996 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Marvin Harrison (WR) in 1997 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Marvin Harrison (WR) in 1998 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Marvin Harrison (WR) in 1999 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Marvin Harrison (WR) in 2000 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Marvin Harrison (WR) in 2001 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Marvin Harrison (WR) in 2002 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Marvin Harrison (WR) in 2003 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Marvin Harrison (WR) in 2004 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Marvin Harrison (WR) in 2005 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Marvin Harrison (WR) in 2006 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Marvin Harrison (WR) in 2007 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Marvin Harrison (WR) in 2008 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Jerome Bettis (RB) in 1993 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/rushing.csv
# Data for Jerome Bettis (RB) in 1994 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Jerome Bettis (RB) in 1995 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Jerome Bettis (RB) in 1996 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Jerome Bettis (RB) in 1997 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/rushing.csv
# Data for Jerome Bettis (RB) in 1998 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/rushing.csv
# Data for Jerome Bettis (RB) in 1999 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/rushing.csv
# Data for Jerome Bettis (RB) in 2000 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for Jerome Bettis (RB) in 2001 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/rushing.csv
# Data for Jerome Bettis (RB) in 2002 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/rushing.csv
# Data for Jerome Bettis (RB) in 2003 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/rushing.csv
# Data for Jerome Bettis (RB) in 2004 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/rushing.csv
# Data for Jerome Bettis (RB) in 2005 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/receiving.csv
# Data for Tim Brown (WR) in 1988 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/receiving.csv
# Data for Tim Brown (WR) in 1989 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/receiving.csv
# Data for Tim Brown (WR) in 1990 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/receiving.csv
# Data for Tim Brown (WR) in 1991 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/receiving.csv
# Data for Tim Brown (WR) in 1992 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/receiving.csv
# Data for Tim Brown (WR) in 1993 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/receiving.csv
# Data for Tim Brown (WR) in 1994 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/receiving.csv
# Data for Tim Brown (WR) in 1995 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Tim Brown (WR) in 1996 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Tim Brown (WR) in 1997 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Tim Brown (WR) in 1998 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Tim Brown (WR) in 1999 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Tim Brown (WR) in 2000 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Tim Brown (WR) in 2001 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Tim Brown (WR) in 2002 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Tim Brown (WR) in 2003 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Tim Brown (WR) in 2004 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/receiving.csv
# Data for Andre Reed (WR) in 1985 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/receiving.csv
# Data for Andre Reed (WR) in 1986 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/receiving.csv
# Data for Andre Reed (WR) in 1987 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/receiving.csv
# Data for Andre Reed (WR) in 1988 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/receiving.csv
# Data for Andre Reed (WR) in 1989 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/receiving.csv
# Data for Andre Reed (WR) in 1990 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/receiving.csv
# Data for Andre Reed (WR) in 1991 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/receiving.csv
# Data for Andre Reed (WR) in 1992 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/receiving.csv
# Data for Andre Reed (WR) in 1993 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/receiving.csv
# Data for Andre Reed (WR) in 1994 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/receiving.csv
# Data for Andre Reed (WR) in 1995 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Andre Reed (WR) in 1996 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Andre Reed (WR) in 1997 successfully scraped.
# ...
# Data for Barry Sanders (RB) in 1990 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/rushing.csv
# Data for Barry Sanders (RB) in 1991 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/rushing.csv
# Data for Barry Sanders (RB) in 1992 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Barry Sanders (RB) in 1993 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/rushing.csv
# Data for Barry Sanders (RB) in 1994 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Barry Sanders (RB) in 1995 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Barry Sanders (RB) in 1996 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Barry Sanders (RB) in 1997 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/rushing.csv
# Data for Barry Sanders (RB) in 1998 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/rushing.csv
# Data for Marcus Allen (RB) in 1982 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/rushing.csv
# Data for Marcus Allen (RB) in 1983 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/rushing.csv
# Data for Marcus Allen (RB) in 1984 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/rushing.csv
# Data for Marcus Allen (RB) in 1985 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/rushing.csv
# Data for Marcus Allen (RB) in 1986 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/rushing.csv
# Data for Marcus Allen (RB) in 1987 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/rushing.csv
# Data for Marcus Allen (RB) in 1988 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/rushing.csv
# Data for Marcus Allen (RB) in 1989 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/rushing.csv
# Data for Marcus Allen (RB) in 1990 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/rushing.csv
# Data for Marcus Allen (RB) in 1991 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/rushing.csv
# Data for Marcus Allen (RB) in 1992 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Marcus Allen (RB) in 1993 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/rushing.csv
# Data for Marcus Allen (RB) in 1994 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Marcus Allen (RB) in 1995 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Marcus Allen (RB) in 1996 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Marcus Allen (RB) in 1997 successfully scraped.
# Scraping data for James Lofton (WR) from year 1978 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1978/player/receiving.csv
# Data for James Lofton (WR) in 1978 successfully scraped.
# Scraping data for James Lofton (WR) from year 1979 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1979/player/receiving.csv
# Data for James Lofton (WR) in 1979 successfully scraped.
# Scraping data for James Lofton (WR) from year 1980 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1980/player/receiving.csv
# Data for James Lofton (WR) in 1980 successfully scraped.
# Scraping data for James Lofton (WR) from year 1981 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1981/player/receiving.csv
# Data for James Lofton (WR) in 1981 successfully scraped.
# Scraping data for James Lofton (WR) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/receiving.csv
# Data for James Lofton (WR) in 1982 successfully scraped.
# Scraping data for James Lofton (WR) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/receiving.csv
# Data for James Lofton (WR) in 1983 successfully scraped.
# Scraping data for James Lofton (WR) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/receiving.csv
# Data for James Lofton (WR) in 1984 successfully scraped.
# Scraping data for James Lofton (WR) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/receiving.csv
# Data for James Lofton (WR) in 1985 successfully scraped.
# Scraping data for James Lofton (WR) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/receiving.csv
# Data for James Lofton (WR) in 1986 successfully scraped.
# Scraping data for James Lofton (WR) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/receiving.csv
# Data for James Lofton (WR) in 1987 successfully scraped.
# Scraping data for James Lofton (WR) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/receiving.csv
# Data for James Lofton (WR) in 1988 successfully scraped.
# Scraping data for James Lofton (WR) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/receiving.csv
# Data for James Lofton (WR) in 1989 successfully scraped.
# Scraping data for James Lofton (WR) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/receiving.csv
# Data for James Lofton (WR) in 1990 successfully scraped.
# Scraping data for James Lofton (WR) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/receiving.csv
# Data for James Lofton (WR) in 1991 successfully scraped.
# Scraping data for James Lofton (WR) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/receiving.csv
# Data for James Lofton (WR) in 1992 successfully scraped.
# Scraping data for James Lofton (WR) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/receiving.csv
# Data for James Lofton (WR) in 1993 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/passing.csv
# Data for Jim Kelly (QB) in 1986 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/passing.csv
# Data for Jim Kelly (QB) in 1987 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/passing.csv
# Data for Jim Kelly (QB) in 1988 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/passing.csv
# Data for Jim Kelly (QB) in 1989 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/passing.csv
# Data for Jim Kelly (QB) in 1990 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/passing.csv
# Data for Jim Kelly (QB) in 1991 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/passing.csv
# Data for Jim Kelly (QB) in 1992 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/passing.csv
# Data for Jim Kelly (QB) in 1993 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/passing.csv
# Data for Jim Kelly (QB) in 1994 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/passing.csv
# Data for Jim Kelly (QB) in 1995 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/passing.csv
# Data for Jim Kelly (QB) in 1996 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1979 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1979/player/passing.csv
# Data for Joe Montana (QB) in 1979 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1980 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1980/player/passing.csv
# Data for Joe Montana (QB) in 1980 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1981 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1981/player/passing.csv
# Data for Joe Montana (QB) in 1981 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/passing.csv
# Data for Joe Montana (QB) in 1982 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/passing.csv
# Data for Joe Montana (QB) in 1983 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/passing.csv
# Data for Joe Montana (QB) in 1984 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/passing.csv
# Data for Joe Montana (QB) in 1985 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/passing.csv
# Data for Joe Montana (QB) in 1986 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/passing.csv
# Data for Joe Montana (QB) in 1987 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/passing.csv
# Data for Joe Montana (QB) in 1988 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/passing.csv
# Data for Joe Montana (QB) in 1989 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/passing.csv
# Data for Joe Montana (QB) in 1990 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/passing.csv
# Data for Joe Montana (QB) in 1991 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/passing.csv
# Data for Joe Montana (QB) in 1992 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/passing.csv
# Data for Joe Montana (QB) in 1993 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/passing.csv
# Data for Joe Montana (QB) in 1994 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/rushing.csv
# Data for Eric Dickerson (RB) in 1983 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/rushing.csv
# Data for Eric Dickerson (RB) in 1984 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/rushing.csv
# Data for Eric Dickerson (RB) in 1985 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/rushing.csv
# Data for Eric Dickerson (RB) in 1986 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/rushing.csv
# Data for Eric Dickerson (RB) in 1987 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/rushing.csv
# Data for Eric Dickerson (RB) in 1988 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/rushing.csv
# Data for Eric Dickerson (RB) in 1989 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/rushing.csv
# Data for Eric Dickerson (RB) in 1990 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/rushing.csv
# Data for Eric Dickerson (RB) in 1991 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/rushing.csv
# Data for Eric Dickerson (RB) in 1992 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Eric Dickerson (RB) in 1993 successfully scraped.

# %%
print(scraped_data)
# Out:
# [{'player': 'Eric Dickerson', 'position': 'RB', 'year': 1983, 'data':               Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0     Eric Dickerson      1808  390  18   11    3   85       116       29.7
# 1    William Andrews      1567  331   7    8    0   27        77       23.3
# 2        Curt Warner      1449  335  13    7    1   60        80       23.9
# 3      Walter Payton      1421  314   6    7    1   49        83       26.4
# 4       John Riggins      1347  375  24    3    1   44        98       26.1
# ..               ...       ...  ...  ..  ...  ...  ...       ...        ...
# 303        Ed Luther       -14    9   0    0    0    8         0        0.0
# 304      Ken Stabler       -14    9   0    0    0    0         0        0.0
# 305    Kenny Duckett       -16    2   0    0    0    2         0        0.0
# 306       Don Strock       -16    6   0    0    0   -2         0        0.0
# 307         Art Monk       -19    3   0    0    0    2         0        0.0
#
#      Rush FUM
# 0          12
# 1           3
# 2           6
# 3           4
# 4           5
# ..        ...
# 303         2
# 304         2
# 305         0
# 306         0
# 307         0
#
# [308 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1984, 'data':                Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0      Eric Dickerson      2105  379  14   18    4   66        95       25.1
# 1       Walter Payton      1684  381  11   10    2   72        82       21.5
# 2        James Wilder      1544  407  13    5    0   37        99       24.3
# 3        Gerald Riggs      1486  353  13    3    1   57        99       28.0
# 4       Wendell Tyler      1262  246   7    8    1   40        59       24.0
# ..                ...       ...  ...  ..  ...  ...  ...       ...        ...
# 287      Irving Fryar       -11    2   0    0    0  -11         0        0.0
# 288    Dwight Collins       -14    3   0    0    0    1         0        0.0
# 289  Stephen Starring       -16    2   0    0    0  -16         0        0.0
# 290      Brian Hansen       -27    2   0    0    0  -12         0        0.0
# 291         Dan Fouts       -29   12   0    0    0    3         0        0.0
#
#      Rush FUM
# 0          13
# 1           3
# 2           8
# 3           8
# 4          13
# ..        ...
# 287         0
# 288         0
# 289         1
# 290         0
# 291         3
#
# [292 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1985, 'data':              Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0      Marcus Allen      1759  380  11    8    1   61        84       22.1
# 1      Gerald Riggs      1719  397  10    7    2   50       104       26.2
# 2     Walter Payton      1551  324   9    7    1   40        81       25.0
# 3        Joe Morris      1336  294  21    7    4   65        74       25.2
# 4    Freeman McNeil      1331  294   3    7    1   69        53       18.0
# ..              ...       ...  ...  ..  ...  ...  ...       ...        ...
# 274   Mark Herrmann        -8   18   0    0    0   11         1        5.6
# 275   Billy Johnson        -8    8   0    0    0    6         1       12.5
# 276     Lynn Dickey       -12   18   1    0    0    3         3       16.7
# 277    Bernie Kosar       -12   26   1    0    0   10         1        3.8
# 278      Dan Marino       -24   26   0    0    0    6         0        0.0
#
#      Rush FUM
# 0           3
# 1           0
# 2           5
# 3           6
# 4           7
# ..        ...
# 274         7
# 275         0
# 276         8
# 277         9
# 278         5
#
# [279 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1986, 'data':                Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0      Eric Dickerson      1821  404  11   10    2   42        98       24.3
# 1          Joe Morris      1516  341  14   11    3   54        73       21.4
# 2         Curt Warner      1481  319  13    8    1   60        75       23.5
# 3        Rueben Mayes      1353  286   8   12    1   50        63       22.0
# 4       Walter Payton      1333  321   8    3    1   41        77       24.0
# ..                ...       ...  ...  ..  ...  ...  ...       ...        ...
# 267       Bill Renner         0    1   0    0    0    0         0        0.0
# 268  Stephen Starring         0    1   0    0    0    0         0        0.0
# 269        Don Strock         0    1   0    0    0    0         0        0.0
# 270       Karl Swanke         0    1   0    0    0    0         0        0.0
# 271    John Teltschik         0    1   0    0    0    0         0        0.0
#
#      Rush FUM
# 0          11
# 1           6
# 2           5
# 3           4
# 4           6
# ..        ...
# 267         0
# 268         1
# 269         1
# 270         1
# 271         0
#
# [272 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1987, 'data':               Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0      Charles White      1374  324  11    5    2   58        74       22.8
# 1     Eric Dickerson      1288  283   6    7    2   57        65       23.0
# 2        Curt Warner       985  234   8    4    1   57        57       24.4
# 3        Mike Rozier       957  229   3    2    1   41        52       22.7
# 4       Rueben Mayes       917  243   5    6    0   38        44       18.1
# ..               ...       ...  ...  ..  ...  ...  ...       ...        ...
# 461    Lionel Manuel       -10    1   0    0    0  -10         0        0.0
# 462        Tim McGee       -10    1   0    0    0  -10         0        0.0
# 463  Tommy Barnhardt       -13    1   0    0    0  -13         0        0.0
# 464    Ernest Givins       -13    1   0    0    0  -13         0        0.0
# 465     Lenny Taylor       -13    1   0    0    0  -13         0        0.0
#
#      Rush FUM
# 0           8
# 1           7
# 2           4
# 3           5
# 4           7
# ..        ...
# 461         0
# 462         0
# 463         0
# 464         0
# 465         0
#
# [466 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1988, 'data':               Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0     Eric Dickerson      1659  388  14    5    2   41       106       27.3
# 1    Herschel Walker      1514  361   5    7    0   38        76       21.0
# 2        Roger Craig      1502  310   9    6    1   46        79       25.5
# 3          Greg Bell      1212  288  16    5    1   44        76       26.4
# 4      John Stephens      1168  297   4    5    1   52        61       20.5
# ..               ...       ...  ...  ..  ...  ...  ...       ...        ...
# 284  Ferrell Edmunds        -8    1   0    0    0   -8         0        0.0
# 285    Gary Hogeboom        -8   11   1    0    0    6         3       27.3
# 286       Bruce Hill       -11    2   0    0    0    3         0        0.0
# 287     Greg Coleman       -13    2   0    0    0    0         0        0.0
# 288       Dan Marino       -17   20   0    0    0    6         1        5.0
#
#      Rush FUM
# 0           4
# 1           6
# 2           4
# 3           5
# 4           3
# ..        ...
# 284         0
# 285         1
# 286         1
# 287         1
# 288         7
#
# [289 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1989, 'data':               Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0    Christian Okoye      1480  370  12    3    1   59        77       20.8
# 1      Barry Sanders      1470  280  14   12    0   34        80       28.6
# 2     Eric Dickerson      1311  314   7    2    0   21        77       24.5
# 3      Neal Anderson      1275  274  11    7    3   73        65       23.7
# 4    Dalton Hilliard      1262  344  13    5    1   40        67       19.5
# ..               ...       ...  ...  ..  ...  ...  ...       ...        ...
# 301    Carlos Carson        -9    1   0    0    0   -9         0        0.0
# 302   Brett Perriman       -10    1   0    0    0  -10         0        0.0
# 303       Rohn Stark       -11    1   0    0    0  -11         0        0.0
# 304       Ron Morris       -14    1   0    0    0  -14         0        0.0
# 305      Floyd Dixon       -23    2   0    0    0  -23         0        0.0
#
#      Rush FUM
# 0           8
# 1           9
# 2          10
# 3           5
# 4           6
# ..        ...
# 301         0
# 302         0
# 303         0
# 304         0
# 305         0
#
# [306 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1990, 'data':              Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0     Barry Sanders      1304  255  13    9    1   45         0        0.0
# 1    Thurman Thomas      1297  271  11    8    3   80        58       21.4
# 2      Marion Butts      1225  265   8    8    3   52         0        0.0
# 3     Earnest Byner      1219  297   6    3    0   22         0        0.0
# 4    Bobby Humphrey      1202  288   7    5    0   37         0        0.0
# ..              ...       ...  ...  ..  ...  ...  ...       ...        ...
# 271    Maury Buford        -9    1   0    0    0   -9         0        0.0
# 272  Rich Camarillo       -11    1   0    0    0  -11         0        0.0
# 273     Hugh Millen       -12    7   0    0    0    2         0        0.0
# 274  Michael Barber       -13    1   0    0    0  -13         0        0.0
# 275   Keith English       -19    2   0    0    0   -8         0        0.0
#
#      Rush FUM
# 0           0
# 1           5
# 2           0
# 3           0
# 4           0
# ..        ...
# 271         0
# 272         0
# 273         0
# 274         0
# 275         0
#
# [276 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1991, 'data':               Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0       Emmitt Smith      1563  365  12    7    2   75        77       21.1
# 1      Barry Sanders      1548  342  16   11    6   69        91       26.6
# 2     Thurman Thomas      1407  288   7   11    0   33        62       21.5
# 3     Rodney Hampton      1059  256  10    5    1   44        58       22.7
# 4      Earnest Byner      1048  274   5    4    0   32        45       16.4
# ..               ...       ...  ...  ..  ...  ...  ...       ...        ...
# 253   Dan Stryzinski       -11    4   0    0    0    0         0        0.0
# 254    Jeff Rutledge       -13    8   0    0    0   -1         0        0.0
# 255       Rohn Stark       -13    1   0    0    0  -13         0        0.0
# 256  Steve Beuerlein       -14    7   0    0    0   -1         0        0.0
# 257     Steve DeBerg       -15   21   0    0    0    0         0        0.0
#
#      Rush FUM
# 0           5
# 1           5
# 2           4
# 3           4
# 4           3
# ..        ...
# 253         1
# 254         0
# 255         1
# 256         0
# 257         3
#
# [258 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1992, 'data':               Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0       Emmitt Smith      1713  373  18   10    2   68        91       24.4
# 1       Barry Foster      1690  390  11   13    2   69        86       22.0
# 2     Thurman Thomas      1487  312   9    8    2   44        78       25.0
# 3      Barry Sanders      1352  312   9    8    3   55        68       21.8
# 4      Lorenzo White      1226  265   7    2    1   44        75       28.3
# ..               ...       ...  ...  ..  ...  ...  ...       ...        ...
# 269     Willie Davis       -11    1   0    0    0  -11         0        0.0
# 270     Jeff Gossett       -12    1   0    0    0  -12         0        0.0
# 271        John Kidd       -13    2   0    0    0  -13         0        0.0
# 272  Greg Montgomery       -14    2   0    0    0    0         0        0.0
# 273     Fred Barnett       -15    1   0    0    0  -15         0        0.0
#
#      Rush FUM
# 0           2
# 1           8
# 2           4
# 3           6
# 4           2
# ..        ...
# 269         0
# 270         1
# 271         1
# 272         1
# 273         0
#
# [274 rows x 10 columns]}, {'player': 'Eric Dickerson', 'position': 'RB', 'year': 1993, 'data':                Player  Rush Yds  Att  TD  20+  40+  Lng  Rush 1st  Rush 1st%  \
# 0        Emmitt Smith      1486  283   9   11    3   62        74       26.2
# 1       Jerome Bettis      1429  294   7    6    2   71        79       26.9
# 2      Thurman Thomas      1315  355   6    3    0   27        70       19.7
# 3        Erric Pegram      1185  292   3    4    0   29        65       22.3
# 4       Barry Sanders      1115  243   3   16    1   42        46       18.9
# ..                ...       ...  ...  ..  ...  ...  ...       ...        ...
# 271  Harold Alexander        -7    2   0    0    0   -7         0        0.0
# 272     Jason Garrett        -8    8   0    0    0   -1         0        0.0
# 273      Jeff Gossett       -10    1   0    0    0  -10         0        0.0
# 274         John Kidd       -13    3   1    0    0    2         1       33.3
# 275      Louie Aguiar       -27    3   0    0    0    5         0        0.0
#
#      Rush FUM
# 0           4
# 1           3
# 2           6
# 3           5
# 4           2
# ..        ...
# 271         0
# 272         1
# 273         0
# 274         0
# 275         1
#
# [276 rows x 10 columns]}]

# %%
import pandas as pd
import requests
from io import StringIO

def construct_url(position, year):
    """Construct URL based on the player's position and year."""
    base_url = "https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/{year}/player/"
    if position == 'QB':
        return base_url.format(year=year) + "passing.csv"
    elif position == 'RB':
        return base_url.format(year=year) + "rushing.csv"
    elif position in ['WR', 'TE']:
        return base_url.format(year=year) + "receiving.csv"
    elif position == 'K':
        return base_url.format(year=year) + "field-goals.csv"
    return None

def scrape_data(player_name, position, start_year, end_year):
    """Scrape data for each player and year."""
    scraped_data = []
    
    for year in range(int(start_year), int(end_year) + 1):
        url = construct_url(position, year)
        if url:
            print(f"Scraping data for {player_name} ({position}) from year {year} at {url}")
            try:
                response = requests.get(url)
                
                if response.status_code == 200:
                    # Use StringIO to read the content as if it were a file
                    csv_data = StringIO(response.text)
                    
                    try:
                        # Try reading the CSV with a comma delimiter
                        df = pd.read_csv(csv_data, delimiter=',')
                        df['player'] = player_name
                        df['position'] = position
                        df['year'] = year
                        scraped_data.append(df)
                        print(f"Data for {player_name} ({position}) in {year} successfully scraped.")
                    except pd.errors.ParserError:
                        # If comma delimiter fails, try reading with a semicolon
                        df = pd.read_csv(csv_data, delimiter=';')
                        df['player'] = player_name
                        df['position'] = position
                        df['year'] = year
                        scraped_data.append(df)
                        print(f"Data for {player_name} ({position}) in {year} scraped with semicolon delimiter.")
                else:
                    print(f"Failed to retrieve data for {player_name} ({position}) from year {year} at {url}")
            except Exception as e:
                print(f"Error scraping data for {player_name} ({position}) from year {year}: {e}")
    
    # Combine the data for all years into a single DataFrame
    return pd.concat(scraped_data, ignore_index=True)

# Load your 'hof_df_filtered' CSV
hof_df = pd.read_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\hof_df_filtered.csv")

# Initialize an empty list to store the scraped data for all players
all_player_data = []

# Loop through each player in your 'hof_df_filtered' CSV
for index, row in hof_df.iterrows():
    player_name = row['player']
    position = row['position']
    start_year = row['from']
    end_year = row['to']
    
    # Scrape data for the current player
    player_data = scrape_data(player_name, position, start_year, end_year)
    
    # Append the data for this player to the list
    all_player_data.append(player_data)

# Combine all the data into one single DataFrame
final_df = pd.concat(all_player_data, ignore_index=True)

# Save the final DataFrame to a CSV file
final_df.to_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\combined_player_data.csv", index=False)

print("Scraping complete. Data saved to 'combined_player_data.csv'.")
# Out:
# Scraping data for Calvin Johnson (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Calvin Johnson (WR) in 2007 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Calvin Johnson (WR) in 2008 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Calvin Johnson (WR) in 2009 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Calvin Johnson (WR) in 2010 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/receiving.csv
# Data for Calvin Johnson (WR) in 2011 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/receiving.csv
# Data for Calvin Johnson (WR) in 2012 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2013 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2013/player/receiving.csv
# Data for Calvin Johnson (WR) in 2013 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2014 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2014/player/receiving.csv
# Data for Calvin Johnson (WR) in 2014 successfully scraped.
# Scraping data for Calvin Johnson (WR) from year 2015 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2015/player/receiving.csv
# Data for Calvin Johnson (WR) in 2015 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/passing.csv
# Data for Peyton Manning (QB) in 1998 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/passing.csv
# Data for Peyton Manning (QB) in 1999 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/passing.csv
# Data for Peyton Manning (QB) in 2000 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/passing.csv
# Data for Peyton Manning (QB) in 2001 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/passing.csv
# Data for Peyton Manning (QB) in 2002 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/passing.csv
# Data for Peyton Manning (QB) in 2003 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/passing.csv
# Data for Peyton Manning (QB) in 2004 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/passing.csv
# Data for Peyton Manning (QB) in 2005 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/passing.csv
# Data for Peyton Manning (QB) in 2006 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/passing.csv
# Data for Peyton Manning (QB) in 2007 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/passing.csv
# Data for Peyton Manning (QB) in 2008 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/passing.csv
# Data for Peyton Manning (QB) in 2009 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/passing.csv
# Data for Peyton Manning (QB) in 2010 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/passing.csv
# Data for Peyton Manning (QB) in 2011 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/passing.csv
# Data for Peyton Manning (QB) in 2012 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2013 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2013/player/passing.csv
# Data for Peyton Manning (QB) in 2013 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2014 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2014/player/passing.csv
# Data for Peyton Manning (QB) in 2014 successfully scraped.
# Scraping data for Peyton Manning (QB) from year 2015 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2015/player/passing.csv
# Data for Peyton Manning (QB) in 2015 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/receiving.csv
# Data for Isaac Bruce (WR) in 1994 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/receiving.csv
# Data for Isaac Bruce (WR) in 1995 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Isaac Bruce (WR) in 1996 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Isaac Bruce (WR) in 1997 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Isaac Bruce (WR) in 1998 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Isaac Bruce (WR) in 1999 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Isaac Bruce (WR) in 2000 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Isaac Bruce (WR) in 2001 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Isaac Bruce (WR) in 2002 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Isaac Bruce (WR) in 2003 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Isaac Bruce (WR) in 2004 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Isaac Bruce (WR) in 2005 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Isaac Bruce (WR) in 2006 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Isaac Bruce (WR) in 2007 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Isaac Bruce (WR) in 2008 successfully scraped.
# Scraping data for Isaac Bruce (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Isaac Bruce (WR) in 2009 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/rushing.csv
# Data for Edgerrin James (RB) in 1999 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/rushing.csv
# Data for Edgerrin James (RB) in 2000 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for Edgerrin James (RB) in 2001 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/rushing.csv
# Data for Edgerrin James (RB) in 2002 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/rushing.csv
# Data for Edgerrin James (RB) in 2003 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/rushing.csv
# Data for Edgerrin James (RB) in 2004 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/rushing.csv
# Data for Edgerrin James (RB) in 2005 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/rushing.csv
# Data for Edgerrin James (RB) in 2006 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/rushing.csv
# Data for Edgerrin James (RB) in 2007 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/rushing.csv
# Data for Edgerrin James (RB) in 2008 successfully scraped.
# Scraping data for Edgerrin James (RB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/rushing.csv
# Data for Edgerrin James (RB) in 2009 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Tony Gonzalez (TE) in 1997 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Tony Gonzalez (TE) in 1998 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Tony Gonzalez (TE) in 1999 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2000 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2001 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2002 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2003 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2004 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2005 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2006 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2007 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2008 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2009 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2010 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2011 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2012 successfully scraped.
# Scraping data for Tony Gonzalez (TE) from year 2013 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2013/player/receiving.csv
# Data for Tony Gonzalez (TE) in 2013 successfully scraped.
# Scraping data for Randy Moss (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Randy Moss (WR) in 1998 successfully scraped.
# Scraping data for Randy Moss (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Randy Moss (WR) in 1999 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Randy Moss (WR) in 2000 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Randy Moss (WR) in 2001 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Randy Moss (WR) in 2002 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Randy Moss (WR) in 2003 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Randy Moss (WR) in 2004 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Randy Moss (WR) in 2005 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Randy Moss (WR) in 2006 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Randy Moss (WR) in 2007 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Randy Moss (WR) in 2008 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Randy Moss (WR) in 2009 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Randy Moss (WR) in 2010 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/receiving.csv
# Data for Randy Moss (WR) in 2011 successfully scraped.
# Scraping data for Randy Moss (WR) from year 2012 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2012/player/receiving.csv
# Data for Randy Moss (WR) in 2012 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Terrell Owens (WR) in 1996 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Terrell Owens (WR) in 1997 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Terrell Owens (WR) in 1998 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Terrell Owens (WR) in 1999 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Terrell Owens (WR) in 2000 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Terrell Owens (WR) in 2001 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Terrell Owens (WR) in 2002 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Terrell Owens (WR) in 2003 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Terrell Owens (WR) in 2004 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Terrell Owens (WR) in 2005 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Terrell Owens (WR) in 2006 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Terrell Owens (WR) in 2007 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Terrell Owens (WR) in 2008 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/receiving.csv
# Data for Terrell Owens (WR) in 2009 successfully scraped.
# Scraping data for Terrell Owens (WR) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/receiving.csv
# Data for Terrell Owens (WR) in 2010 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/field-goals.csv
# Data for Morten Andersen (K) in 1982 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/field-goals.csv
# Data for Morten Andersen (K) in 1983 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/field-goals.csv
# Data for Morten Andersen (K) in 1984 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/field-goals.csv
# Data for Morten Andersen (K) in 1985 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/field-goals.csv
# Data for Morten Andersen (K) in 1986 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/field-goals.csv
# Data for Morten Andersen (K) in 1987 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/field-goals.csv
# Data for Morten Andersen (K) in 1988 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/field-goals.csv
# Data for Morten Andersen (K) in 1989 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/field-goals.csv
# Data for Morten Andersen (K) in 1990 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/field-goals.csv
# Data for Morten Andersen (K) in 1991 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/field-goals.csv
# Data for Morten Andersen (K) in 1992 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/field-goals.csv
# Data for Morten Andersen (K) in 1993 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/field-goals.csv
# Data for Morten Andersen (K) in 1994 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/field-goals.csv
# Data for Morten Andersen (K) in 1995 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/field-goals.csv
# Data for Morten Andersen (K) in 1996 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/field-goals.csv
# Data for Morten Andersen (K) in 1997 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/field-goals.csv
# Data for Morten Andersen (K) in 1998 successfully scraped.
# Scraping data for Morten Andersen (K) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/field-goals.csv
# Data for Morten Andersen (K) in 1999 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/field-goals.csv
# Data for Morten Andersen (K) in 2000 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/field-goals.csv
# Data for Morten Andersen (K) in 2001 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/field-goals.csv
# Data for Morten Andersen (K) in 2002 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/field-goals.csv
# Data for Morten Andersen (K) in 2003 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/field-goals.csv
# Data for Morten Andersen (K) in 2004 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/field-goals.csv
# Data for Morten Andersen (K) in 2005 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/field-goals.csv
# Data for Morten Andersen (K) in 2006 successfully scraped.
# Scraping data for Morten Andersen (K) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/field-goals.csv
# Data for Morten Andersen (K) in 2007 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Terrell Davis (RB) in 1995 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Terrell Davis (RB) in 1996 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Terrell Davis (RB) in 1997 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/rushing.csv
# Data for Terrell Davis (RB) in 1998 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/rushing.csv
# Data for Terrell Davis (RB) in 1999 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/rushing.csv
# Data for Terrell Davis (RB) in 2000 successfully scraped.
# Scraping data for Terrell Davis (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for Terrell Davis (RB) in 2001 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2001 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2002 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2003 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2004 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2005 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2006 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2007 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2008 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2009 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2010 successfully scraped.
# Scraping data for LaDainian Tomlinson (RB) from year 2011 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2011/player/rushing.csv
# Data for LaDainian Tomlinson (RB) in 2011 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/passing.csv
# Data for Kurt Warner (QB) in 1998 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/passing.csv
# Data for Kurt Warner (QB) in 1999 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/passing.csv
# Data for Kurt Warner (QB) in 2000 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/passing.csv
# Data for Kurt Warner (QB) in 2001 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/passing.csv
# Data for Kurt Warner (QB) in 2002 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/passing.csv
# Data for Kurt Warner (QB) in 2003 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/passing.csv
# Data for Kurt Warner (QB) in 2004 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/passing.csv
# Data for Kurt Warner (QB) in 2005 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/passing.csv
# Data for Kurt Warner (QB) in 2006 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/passing.csv
# Data for Kurt Warner (QB) in 2007 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/passing.csv
# Data for Kurt Warner (QB) in 2008 successfully scraped.
# Scraping data for Kurt Warner (QB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/passing.csv
# Data for Kurt Warner (QB) in 2009 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/passing.csv
# Data for Brett Favre (QB) in 1991 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/passing.csv
# Data for Brett Favre (QB) in 1992 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/passing.csv
# Data for Brett Favre (QB) in 1993 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/passing.csv
# Data for Brett Favre (QB) in 1994 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/passing.csv
# Data for Brett Favre (QB) in 1995 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/passing.csv
# Data for Brett Favre (QB) in 1996 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/passing.csv
# Data for Brett Favre (QB) in 1997 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/passing.csv
# Data for Brett Favre (QB) in 1998 successfully scraped.
# Scraping data for Brett Favre (QB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/passing.csv
# Data for Brett Favre (QB) in 1999 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/passing.csv
# Data for Brett Favre (QB) in 2000 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/passing.csv
# Data for Brett Favre (QB) in 2001 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/passing.csv
# Data for Brett Favre (QB) in 2002 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/passing.csv
# Data for Brett Favre (QB) in 2003 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/passing.csv
# Data for Brett Favre (QB) in 2004 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/passing.csv
# Data for Brett Favre (QB) in 2005 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/passing.csv
# Data for Brett Favre (QB) in 2006 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/passing.csv
# Data for Brett Favre (QB) in 2007 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/passing.csv
# Data for Brett Favre (QB) in 2008 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2009 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2009/player/passing.csv
# Data for Brett Favre (QB) in 2009 successfully scraped.
# Scraping data for Brett Favre (QB) from year 2010 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2010/player/passing.csv
# Data for Brett Favre (QB) in 2010 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Marvin Harrison (WR) in 1996 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Marvin Harrison (WR) in 1997 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Marvin Harrison (WR) in 1998 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Marvin Harrison (WR) in 1999 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Marvin Harrison (WR) in 2000 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Marvin Harrison (WR) in 2001 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Marvin Harrison (WR) in 2002 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Marvin Harrison (WR) in 2003 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Marvin Harrison (WR) in 2004 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/receiving.csv
# Data for Marvin Harrison (WR) in 2005 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2006 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2006/player/receiving.csv
# Data for Marvin Harrison (WR) in 2006 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2007 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2007/player/receiving.csv
# Data for Marvin Harrison (WR) in 2007 successfully scraped.
# Scraping data for Marvin Harrison (WR) from year 2008 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2008/player/receiving.csv
# Data for Marvin Harrison (WR) in 2008 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Jerome Bettis (RB) in 1993 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/rushing.csv
# Data for Jerome Bettis (RB) in 1994 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Jerome Bettis (RB) in 1995 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Jerome Bettis (RB) in 1996 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Jerome Bettis (RB) in 1997 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/rushing.csv
# Data for Jerome Bettis (RB) in 1998 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/rushing.csv
# Data for Jerome Bettis (RB) in 1999 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/rushing.csv
# Data for Jerome Bettis (RB) in 2000 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/rushing.csv
# Data for Jerome Bettis (RB) in 2001 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/rushing.csv
# Data for Jerome Bettis (RB) in 2002 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/rushing.csv
# Data for Jerome Bettis (RB) in 2003 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/rushing.csv
# Data for Jerome Bettis (RB) in 2004 successfully scraped.
# Scraping data for Jerome Bettis (RB) from year 2005 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2005/player/rushing.csv
# Data for Jerome Bettis (RB) in 2005 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/receiving.csv
# Data for Tim Brown (WR) in 1988 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/receiving.csv
# Data for Tim Brown (WR) in 1989 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/receiving.csv
# Data for Tim Brown (WR) in 1990 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/receiving.csv
# Data for Tim Brown (WR) in 1991 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/receiving.csv
# Data for Tim Brown (WR) in 1992 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/receiving.csv
# Data for Tim Brown (WR) in 1993 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/receiving.csv
# Data for Tim Brown (WR) in 1994 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/receiving.csv
# Data for Tim Brown (WR) in 1995 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Tim Brown (WR) in 1996 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Tim Brown (WR) in 1997 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/receiving.csv
# Data for Tim Brown (WR) in 1998 successfully scraped.
# Scraping data for Tim Brown (WR) from year 1999 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1999/player/receiving.csv
# Data for Tim Brown (WR) in 1999 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2000 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2000/player/receiving.csv
# Data for Tim Brown (WR) in 2000 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2001 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2001/player/receiving.csv
# Data for Tim Brown (WR) in 2001 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2002 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2002/player/receiving.csv
# Data for Tim Brown (WR) in 2002 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2003 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2003/player/receiving.csv
# Data for Tim Brown (WR) in 2003 successfully scraped.
# Scraping data for Tim Brown (WR) from year 2004 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/2004/player/receiving.csv
# Data for Tim Brown (WR) in 2004 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/receiving.csv
# Data for Andre Reed (WR) in 1985 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/receiving.csv
# Data for Andre Reed (WR) in 1986 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/receiving.csv
# Data for Andre Reed (WR) in 1987 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/receiving.csv
# Data for Andre Reed (WR) in 1988 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/receiving.csv
# Data for Andre Reed (WR) in 1989 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/receiving.csv
# Data for Andre Reed (WR) in 1990 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/receiving.csv
# Data for Andre Reed (WR) in 1991 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/receiving.csv
# Data for Andre Reed (WR) in 1992 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/receiving.csv
# Data for Andre Reed (WR) in 1993 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/receiving.csv
# Data for Andre Reed (WR) in 1994 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/receiving.csv
# Data for Andre Reed (WR) in 1995 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/receiving.csv
# Data for Andre Reed (WR) in 1996 successfully scraped.
# Scraping data for Andre Reed (WR) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/receiving.csv
# Data for Andre Reed (WR) in 1997 successfully scraped.
# ...
# Data for Barry Sanders (RB) in 1990 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/rushing.csv
# Data for Barry Sanders (RB) in 1991 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/rushing.csv
# Data for Barry Sanders (RB) in 1992 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Barry Sanders (RB) in 1993 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/rushing.csv
# Data for Barry Sanders (RB) in 1994 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Barry Sanders (RB) in 1995 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Barry Sanders (RB) in 1996 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Barry Sanders (RB) in 1997 successfully scraped.
# Scraping data for Barry Sanders (RB) from year 1998 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1998/player/rushing.csv
# Data for Barry Sanders (RB) in 1998 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/rushing.csv
# Data for Marcus Allen (RB) in 1982 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/rushing.csv
# Data for Marcus Allen (RB) in 1983 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/rushing.csv
# Data for Marcus Allen (RB) in 1984 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/rushing.csv
# Data for Marcus Allen (RB) in 1985 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/rushing.csv
# Data for Marcus Allen (RB) in 1986 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/rushing.csv
# Data for Marcus Allen (RB) in 1987 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/rushing.csv
# Data for Marcus Allen (RB) in 1988 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/rushing.csv
# Data for Marcus Allen (RB) in 1989 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/rushing.csv
# Data for Marcus Allen (RB) in 1990 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/rushing.csv
# Data for Marcus Allen (RB) in 1991 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/rushing.csv
# Data for Marcus Allen (RB) in 1992 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Marcus Allen (RB) in 1993 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/rushing.csv
# Data for Marcus Allen (RB) in 1994 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/rushing.csv
# Data for Marcus Allen (RB) in 1995 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/rushing.csv
# Data for Marcus Allen (RB) in 1996 successfully scraped.
# Scraping data for Marcus Allen (RB) from year 1997 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1997/player/rushing.csv
# Data for Marcus Allen (RB) in 1997 successfully scraped.
# Scraping data for James Lofton (WR) from year 1978 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1978/player/receiving.csv
# Data for James Lofton (WR) in 1978 successfully scraped.
# Scraping data for James Lofton (WR) from year 1979 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1979/player/receiving.csv
# Data for James Lofton (WR) in 1979 successfully scraped.
# Scraping data for James Lofton (WR) from year 1980 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1980/player/receiving.csv
# Data for James Lofton (WR) in 1980 successfully scraped.
# Scraping data for James Lofton (WR) from year 1981 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1981/player/receiving.csv
# Data for James Lofton (WR) in 1981 successfully scraped.
# Scraping data for James Lofton (WR) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/receiving.csv
# Data for James Lofton (WR) in 1982 successfully scraped.
# Scraping data for James Lofton (WR) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/receiving.csv
# Data for James Lofton (WR) in 1983 successfully scraped.
# Scraping data for James Lofton (WR) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/receiving.csv
# Data for James Lofton (WR) in 1984 successfully scraped.
# Scraping data for James Lofton (WR) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/receiving.csv
# Data for James Lofton (WR) in 1985 successfully scraped.
# Scraping data for James Lofton (WR) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/receiving.csv
# Data for James Lofton (WR) in 1986 successfully scraped.
# Scraping data for James Lofton (WR) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/receiving.csv
# Data for James Lofton (WR) in 1987 successfully scraped.
# Scraping data for James Lofton (WR) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/receiving.csv
# Data for James Lofton (WR) in 1988 successfully scraped.
# Scraping data for James Lofton (WR) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/receiving.csv
# Data for James Lofton (WR) in 1989 successfully scraped.
# Scraping data for James Lofton (WR) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/receiving.csv
# Data for James Lofton (WR) in 1990 successfully scraped.
# Scraping data for James Lofton (WR) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/receiving.csv
# Data for James Lofton (WR) in 1991 successfully scraped.
# Scraping data for James Lofton (WR) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/receiving.csv
# Data for James Lofton (WR) in 1992 successfully scraped.
# Scraping data for James Lofton (WR) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/receiving.csv
# Data for James Lofton (WR) in 1993 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/passing.csv
# Data for Jim Kelly (QB) in 1986 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/passing.csv
# Data for Jim Kelly (QB) in 1987 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/passing.csv
# Data for Jim Kelly (QB) in 1988 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/passing.csv
# Data for Jim Kelly (QB) in 1989 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/passing.csv
# Data for Jim Kelly (QB) in 1990 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/passing.csv
# Data for Jim Kelly (QB) in 1991 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/passing.csv
# Data for Jim Kelly (QB) in 1992 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/passing.csv
# Data for Jim Kelly (QB) in 1993 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/passing.csv
# Data for Jim Kelly (QB) in 1994 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1995 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1995/player/passing.csv
# Data for Jim Kelly (QB) in 1995 successfully scraped.
# Scraping data for Jim Kelly (QB) from year 1996 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1996/player/passing.csv
# Data for Jim Kelly (QB) in 1996 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1979 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1979/player/passing.csv
# Data for Joe Montana (QB) in 1979 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1980 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1980/player/passing.csv
# Data for Joe Montana (QB) in 1980 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1981 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1981/player/passing.csv
# Data for Joe Montana (QB) in 1981 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1982 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1982/player/passing.csv
# Data for Joe Montana (QB) in 1982 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/passing.csv
# Data for Joe Montana (QB) in 1983 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/passing.csv
# Data for Joe Montana (QB) in 1984 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/passing.csv
# Data for Joe Montana (QB) in 1985 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/passing.csv
# Data for Joe Montana (QB) in 1986 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/passing.csv
# Data for Joe Montana (QB) in 1987 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/passing.csv
# Data for Joe Montana (QB) in 1988 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/passing.csv
# Data for Joe Montana (QB) in 1989 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/passing.csv
# Data for Joe Montana (QB) in 1990 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/passing.csv
# Data for Joe Montana (QB) in 1991 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/passing.csv
# Data for Joe Montana (QB) in 1992 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/passing.csv
# Data for Joe Montana (QB) in 1993 successfully scraped.
# Scraping data for Joe Montana (QB) from year 1994 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1994/player/passing.csv
# Data for Joe Montana (QB) in 1994 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1983 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1983/player/rushing.csv
# Data for Eric Dickerson (RB) in 1983 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1984 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1984/player/rushing.csv
# Data for Eric Dickerson (RB) in 1984 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1985 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1985/player/rushing.csv
# Data for Eric Dickerson (RB) in 1985 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1986 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1986/player/rushing.csv
# Data for Eric Dickerson (RB) in 1986 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1987 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1987/player/rushing.csv
# Data for Eric Dickerson (RB) in 1987 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1988 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1988/player/rushing.csv
# Data for Eric Dickerson (RB) in 1988 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1989 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1989/player/rushing.csv
# Data for Eric Dickerson (RB) in 1989 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1990 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1990/player/rushing.csv
# Data for Eric Dickerson (RB) in 1990 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1991 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1991/player/rushing.csv
# Data for Eric Dickerson (RB) in 1991 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1992 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1992/player/rushing.csv
# Data for Eric Dickerson (RB) in 1992 successfully scraped.
# Scraping data for Eric Dickerson (RB) from year 1993 at https://raw.githubusercontent.com/MarcLinderGit/NFL_Stats/main/data/1993/player/rushing.csv
# Data for Eric Dickerson (RB) in 1993 successfully scraped.
# Scraping complete. Data saved to 'combined_player_data.csv'.

# %%
# Load the data
hof_df = pd.read_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\hof_df_filtered.csv")
combined_player_data = pd.read_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\combined_player_data.csv")

# Create an empty list to store matching rows
matching_data = []

# Loop through the hof_df and check for matches in combined_player_data
for player in hof_df['player']:
    matching_rows = combined_player_data[combined_player_data['Player'] == player]
    
    # If matches are found, append them to the list
    if not matching_rows.empty:
        matching_data.append(matching_rows)

# Combine the matching rows into a single DataFrame
final_df = pd.concat(matching_data, ignore_index=True)

# Save the result to a new CSV
final_df.to_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\matching_player_data.csv", index=False)

print("CSV with matching player data has been created!")
# Out:
# C:\Users\Weekseey\AppData\Local\Temp\ipykernel_18608\3100871465.py:3: DtypeWarning: Columns (31,32,33,34,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_player_data = pd.read_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\combined_player_data.csv")
# CSV with matching player data has been created!

# %% [markdown]
# #### --I'll look into/fix the DtypeWarning for those columns later.--

# %% [markdown]
# # First Glimpse at the Scraped Data

# %%
matching_player_data = pd.read_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\matching_player_data.csv")
print(matching_player_data.head())
# Out:
#            Player   Rec     Yds    TD   20+   40+   LNG  Rec 1st  1st%  \
# 0  Calvin Johnson  48.0   756.0   4.0  12.0   1.0  49.0     38.0  79.2
# 1  Calvin Johnson  78.0  1331.0  12.0  21.0   7.0  96.0     52.0  66.7
# 2  Calvin Johnson  67.0   984.0   5.0  15.0   4.0  75.0     46.0  68.7
# 3  Calvin Johnson  77.0  1120.0  12.0  16.0   3.0  87.0     57.0  74.0
# 4  Calvin Johnson  96.0  1681.0  16.0  32.0  10.0  73.0     77.0  80.2
#
#    Rec FUM  ...  Rush FUM  FGM FG %  1-19 > A-M  20-29 > A-M  30-39 > A-M  \
# 0      1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 1      2.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 2      3.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 3      1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 4      1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
#
#    40-49 > A-M  50-59 > A-M  60+ > A-M  FG Blk
# 0          NaN          NaN        NaN     NaN
# 1          NaN          NaN        NaN     NaN
# 2          NaN          NaN        NaN     NaN
# 3          NaN          NaN        NaN     NaN
# 4          NaN          NaN        NaN     NaN
#
# [5 rows x 38 columns]

# %%
print(matching_player_data.shape)
# Out:
# (5837, 38)

# %%
duplicates = matching_player_data.duplicated()

duplicate_rows = matching_player_data[duplicates]
print(duplicate_rows)
# Out:
#               Player   Rec     Yds    TD   20+  40+   LNG  Rec 1st  1st%  \
# 9     Calvin Johnson  48.0   756.0   4.0  12.0  1.0  49.0     38.0  79.2
# 10    Calvin Johnson  78.0  1331.0  12.0  21.0  7.0  96.0     52.0  66.7
# 11    Calvin Johnson  67.0   984.0   5.0  15.0  4.0  75.0     46.0  68.7
# 22    Calvin Johnson  48.0   756.0   4.0  12.0  1.0  49.0     38.0  79.2
# 23    Calvin Johnson  78.0  1331.0  12.0  21.0  7.0  96.0     52.0  66.7
# ...              ...   ...     ...   ...   ...  ...   ...      ...   ...
# 5832  Eric Dickerson   NaN     NaN   7.0   2.0  0.0   NaN      NaN   NaN
# 5833  Eric Dickerson   NaN     NaN   4.0   3.0  1.0   NaN      NaN   NaN
# 5834  Eric Dickerson   NaN     NaN   2.0   3.0  0.0   NaN      NaN   NaN
# 5835  Eric Dickerson   NaN     NaN   2.0   5.0  1.0   NaN      NaN   NaN
# 5836  Eric Dickerson   NaN     NaN   0.0   0.0  0.0   NaN      NaN   NaN
#
#       Rec FUM  ...  Rush FUM  FGM FG %  1-19 > A-M  20-29 > A-M  30-39 > A-M  \
# 9         1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 10        2.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 11        3.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 22        1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 23        2.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# ...       ...  ...       ...  ...  ...         ...          ...          ...
# 5832      NaN  ...      10.0  NaN  NaN         NaN          NaN          NaN
# 5833      NaN  ...       0.0  NaN  NaN         NaN          NaN          NaN
# 5834      NaN  ...       6.0  NaN  NaN         NaN          NaN          NaN
# 5835      NaN  ...       1.0  NaN  NaN         NaN          NaN          NaN
# 5836      NaN  ...       0.0  NaN  NaN         NaN          NaN          NaN
#
#       40-49 > A-M  50-59 > A-M  60+ > A-M  FG Blk
# 9             NaN          NaN        NaN     NaN
# 10            NaN          NaN        NaN     NaN
# 11            NaN          NaN        NaN     NaN
# 22            NaN          NaN        NaN     NaN
# 23            NaN          NaN        NaN     NaN
# ...           ...          ...        ...     ...
# 5832          NaN          NaN        NaN     NaN
# 5833          NaN          NaN        NaN     NaN
# 5834          NaN          NaN        NaN     NaN
# 5835          NaN          NaN        NaN     NaN
# 5836          NaN          NaN        NaN     NaN
#
# [4568 rows x 38 columns]

# %% [markdown]
# # Remove duplicates

# %%
matching_player_data = matching_player_data.drop_duplicates()

print(matching_player_data.shape)
# Out:
# (1269, 38)

# %%
matching_player_data.to_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\matching_player_data.csv", index=False)

# %% [markdown]
# # Column Dtype Fixing
# It appears with the field goal data, pandas has mistaken the attempts/makes formatting as date formats. (3/4 as 4-Mar)

# %%
# Re-load the CSV with specified columns as strings to prevent date parsing
matching_player_data = pd.read_csv(
    r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\matching_player_data.csv",
    dtype={ '1-19 > A-M': str, '20-29 > A-M': str, '30-39 > A-M': str, 
            '40-49 > A-M': str, '50-59 > A-M': str, '60+ > A-M': str }
)

# View rows from 254 to 278 (index 253 to 277)
matching_player_data.iloc[253:278]
# Out:
#               Player   Rec    Yds   TD  20+  40+   LNG  Rec 1st  1st%  \
# 253  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 254  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 255  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 256  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 257  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 258  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 259  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 260  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 261  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 262  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 263  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 264  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 265  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 266  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 267  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 268  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 269  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 270  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 271  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 272  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 273  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 274  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 275  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 276  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 277    Terrell Davis  49.0  367.0  1.0  2.0  0.0  31.0     18.0  36.7
#
#      Rec FUM  ...  Rush FUM   FGM  FG %  1-19 > A-M  20-29 > A-M  30-39 > A-M  \
# 253      NaN  ...       NaN  18.0  75.0       2-Feb        8-Aug        4-Mar
# 254      NaN  ...       NaN  20.0  74.1         0/0        9-Sep        5-Apr
# 255      NaN  ...       NaN  31.0  88.6         0/0        5-Apr        13/14
# 256      NaN  ...       NaN  26.0  86.7       1-Jan       11-Nov        7-Jun
# 257      NaN  ...       NaN  28.0  77.8       3-Mar        6-Jun        9-Sep
# 258      NaN  ...       NaN  26.0  72.2       1-Jan       12-Nov       11-Aug
# 259      NaN  ...       NaN  20.0  69.0         0/0        8-Jul       11-Oct
# 260      NaN  ...       NaN  21.0  77.8         0/0        5-May        6-May
# 261      NaN  ...       NaN  25.0  78.1         0/0        6-Jun       13-Nov
# 262      NaN  ...       NaN  29.0  85.3         0/0       10-Oct       10-Aug
# 263      NaN  ...       NaN  28.0  80.0       2-Feb        7-Jul        7-Jul
# 264      NaN  ...       NaN  28.0  71.8         0/0        9-Sep       14-Nov
# 265      NaN  ...       NaN  31.0  83.8       1-Jan        8-Aug       11-Nov
# 266      NaN  ...       NaN  22.0  75.9         0/0        5-May       11-Sep
# 267      NaN  ...       NaN  23.0  85.2       1-Jan       10-Oct        7-Jul
# 268      NaN  ...       NaN  23.0  82.1         0/1        9-Aug        7-Jul
# 269      NaN  ...       NaN  15.0  71.4       1-Jan        5-May        8-May
# 270      NaN  ...       NaN  25.0  80.6         0/0        6-Jun        7-Jun
# 271      NaN  ...       NaN  23.0  82.1         0/0        8-Aug        8-Jul
# 272      NaN  ...       NaN  22.0  84.6         0/0        6-Jun       10-Oct
# 273      NaN  ...       NaN  16.0  80.0         0/0        3-Mar        8-Aug
# 274      NaN  ...       NaN  18.0  81.8       1-Jan        8-Aug        7-May
# 275      NaN  ...       NaN  20.0  87.0         0/0        8-Jul        6-Jun
# 276      NaN  ...       NaN  25.0  89.3         0/0        9-Sep       12-Dec
# 277      1.0  ...       NaN   NaN   NaN         NaN          NaN          NaN
#
#      40-49 > A-M  50-59 > A-M  60+ > A-M  FG Blk
# 253        6-Feb          0/0        0/0     2.0
# 254       10-May          0/0        0/0     1.0
# 255       12-Nov          0/0        0/0     1.0
# 256        6-Jun          0/0        0/0     0.0
# 257       12-Aug          0/0        0/0     0.0
# 258        8-May          0/0        0/0     1.0
# 259        6-Mar          0/0        0/0     1.0
# 260       12-Aug          0/0        0/0     1.0
# 261        9-Jun          0/0        0/0     0.0
# 262       11-Aug          0/0        0/0     0.0
# 263       14-Nov          0/0        0/0     0.0
# 264       10-Aug          0/0        0/0     3.0
# 265        8-Mar          0/0        0/0     2.0
# 266        8-Jul          0/0        0/0     1.0
# 267        6-Mar          0/0        0/0     0.0
# 268        9-Jun          0/0        0/0     2.0
# 269        6-Apr          0/0        0/0     1.0
# 270       15-Nov        3-Feb        0/0     0.0
# 271        7-Jun        5-Feb        0/0     0.0
# 272        9-May        1-Jan        0/0     0.0
# 273        8-May          0/1        0/0     1.0
# 274        6-Apr          0/0        0/0     0.0
# 275        8-Jul          0/1        0/0     1.0
# 276        7-Apr          0/0        0/0     1.0
# 277          NaN          NaN        NaN     NaN
#
# [25 rows x 38 columns]

# %%
import re

# Dictionary to map month names to their respective numeric values
month_map = {
    'Jan': '1', 'Feb': '2', 'Mar': '3', 'Apr': '4', 'May': '5', 'Jun': '6',
    'Jul': '7', 'Aug': '8', 'Sep': '9', 'Oct': '10', 'Nov': '11', 'Dec': '12'
}

# Specify columns that need the transformation
columns_to_fix = [
    '1-19 > A-M', '20-29 > A-M', '30-39 > A-M', '40-49 > A-M', 
    '50-59 > A-M', '60+ > A-M'
]

# Function to transform the values like '5-May' to '5/5' (month/day)
def reformat_months(val):
    if isinstance(val, str):  # Only apply regex if it's a string
        # Match patterns like '5-May' and '11-Aug'
        match = re.match(r'(\d{1,2})-(\w{3})', val)
        if match:
            day = match.group(1)
            month_name = match.group(2)
            # Replace month name with numeric month from the map
            month_number = month_map.get(month_name, '')
            return f"{day}/{month_number}"  # Correct the order to day/month
    return val  # Return the value as is if it's not a string or doesn't match

# Apply transformation to the relevant columns
for col in columns_to_fix:
    matching_player_data[col] = matching_player_data[col].apply(reformat_months)

# Check a few rows to verify
matching_player_data.iloc[253:278]
# Out:
#               Player   Rec    Yds   TD  20+  40+   LNG  Rec 1st  1st%  \
# 253  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 254  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 255  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 256  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 257  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 258  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 259  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 260  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 261  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 262  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 263  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 264  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 265  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 266  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 267  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 268  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 269  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 270  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 271  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 272  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 273  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 274  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 275  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 276  Morten Andersen   NaN    NaN  NaN  NaN  NaN   NaN      NaN   NaN
# 277    Terrell Davis  49.0  367.0  1.0  2.0  0.0  31.0     18.0  36.7
#
#      Rec FUM  ...  Rush FUM   FGM  FG %  1-19 > A-M  20-29 > A-M  30-39 > A-M  \
# 253      NaN  ...       NaN  18.0  75.0         2/2          8/8          4/3
# 254      NaN  ...       NaN  20.0  74.1         0/0          9/9          5/4
# 255      NaN  ...       NaN  31.0  88.6         0/0          5/4        13/14
# 256      NaN  ...       NaN  26.0  86.7         1/1        11/11          7/6
# 257      NaN  ...       NaN  28.0  77.8         3/3          6/6          9/9
# 258      NaN  ...       NaN  26.0  72.2         1/1        12/11         11/8
# 259      NaN  ...       NaN  20.0  69.0         0/0          8/7        11/10
# 260      NaN  ...       NaN  21.0  77.8         0/0          5/5          6/5
# 261      NaN  ...       NaN  25.0  78.1         0/0          6/6        13/11
# 262      NaN  ...       NaN  29.0  85.3         0/0        10/10         10/8
# 263      NaN  ...       NaN  28.0  80.0         2/2          7/7          7/7
# 264      NaN  ...       NaN  28.0  71.8         0/0          9/9        14/11
# 265      NaN  ...       NaN  31.0  83.8         1/1          8/8        11/11
# 266      NaN  ...       NaN  22.0  75.9         0/0          5/5         11/9
# 267      NaN  ...       NaN  23.0  85.2         1/1        10/10          7/7
# 268      NaN  ...       NaN  23.0  82.1         0/1          9/8          7/7
# 269      NaN  ...       NaN  15.0  71.4         1/1          5/5          8/5
# 270      NaN  ...       NaN  25.0  80.6         0/0          6/6          7/6
# 271      NaN  ...       NaN  23.0  82.1         0/0          8/8          8/7
# 272      NaN  ...       NaN  22.0  84.6         0/0          6/6        10/10
# 273      NaN  ...       NaN  16.0  80.0         0/0          3/3          8/8
# 274      NaN  ...       NaN  18.0  81.8         1/1          8/8          7/5
# 275      NaN  ...       NaN  20.0  87.0         0/0          8/7          6/6
# 276      NaN  ...       NaN  25.0  89.3         0/0          9/9        12/12
# 277      1.0  ...       NaN   NaN   NaN         NaN          NaN          NaN
#
#      40-49 > A-M  50-59 > A-M  60+ > A-M  FG Blk
# 253          6/2          0/0        0/0     2.0
# 254         10/5          0/0        0/0     1.0
# 255        12/11          0/0        0/0     1.0
# 256          6/6          0/0        0/0     0.0
# 257         12/8          0/0        0/0     0.0
# 258          8/5          0/0        0/0     1.0
# 259          6/3          0/0        0/0     1.0
# 260         12/8          0/0        0/0     1.0
# 261          9/6          0/0        0/0     0.0
# 262         11/8          0/0        0/0     0.0
# 263        14/11          0/0        0/0     0.0
# 264         10/8          0/0        0/0     3.0
# 265          8/3          0/0        0/0     2.0
# 266          8/7          0/0        0/0     1.0
# 267          6/3          0/0        0/0     0.0
# 268          9/6          0/0        0/0     2.0
# 269          6/4          0/0        0/0     1.0
# 270        15/11          3/2        0/0     0.0
# 271          7/6          5/2        0/0     0.0
# 272          9/5          1/1        0/0     0.0
# 273          8/5          0/1        0/0     1.0
# 274          6/4          0/0        0/0     0.0
# 275          8/7          0/1        0/0     1.0
# 276          7/4          0/0        0/0     1.0
# 277          NaN          NaN        NaN     NaN
#
# [25 rows x 38 columns]

# %% [markdown]
# # Both WR and TE positions listed for same player and year, giving identical receiving stats

# %%
# Duplicates based on player, year, and all the receiving stats columns
receiving_columns = ['Rec', 'Yds', 'TD', '20+', '40+', 'Lng', 'Rec 1st', '1st%', 'Rec FUM', 'Rec YAC/R', 'Tgts']
duplicates = matching_player_data[matching_player_data.duplicated(subset=['Player', 'year'] + receiving_columns, keep=False)]

# Display the duplicate rows
print(duplicates)
# Out:
#               Player   Rec     Yds    TD   20+   40+   LNG  Rec 1st  1st%  \
# 0     Calvin Johnson  48.0   756.0   4.0  12.0   1.0  49.0     38.0  79.2
# 1     Calvin Johnson  78.0  1331.0  12.0  21.0   7.0  96.0     52.0  66.7
# 2     Calvin Johnson  67.0   984.0   5.0  15.0   4.0  75.0     46.0  68.7
# 3     Calvin Johnson  77.0  1120.0  12.0  16.0   3.0  87.0     57.0  74.0
# 4     Calvin Johnson  96.0  1681.0  16.0  32.0  10.0  73.0     77.0  80.2
# ...              ...   ...     ...   ...   ...   ...   ...      ...   ...
# 1246  Eric Dickerson   6.0    58.0   0.0   1.0   0.0  30.0      2.0  33.3
# 1250  Eric Dickerson  18.0    92.0   0.0   0.0   0.0  17.0      0.0   0.0
# 1251  Eric Dickerson  41.0   269.0   1.0   1.0   0.0  26.0     13.0  31.7
# 1252  Eric Dickerson  14.0    85.0   1.0   0.0   0.0  15.0      5.0  35.7
# 1253  Eric Dickerson   6.0    58.0   0.0   1.0   0.0  30.0      2.0  33.3
#
#       Rec FUM  ...  Rush FUM  FGM FG %  1-19 > A-M  20-29 > A-M  30-39 > A-M  \
# 0         1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 1         2.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 2         3.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 3         1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 4         1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# ...       ...  ...       ...  ...  ...         ...          ...          ...
# 1246      0.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 1250      0.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 1251      0.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 1252      0.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 1253      0.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
#
#       40-49 > A-M  50-59 > A-M  60+ > A-M  FG Blk
# 0             NaN          NaN        NaN     NaN
# 1             NaN          NaN        NaN     NaN
# 2             NaN          NaN        NaN     NaN
# 3             NaN          NaN        NaN     NaN
# 4             NaN          NaN        NaN     NaN
# ...           ...          ...        ...     ...
# 1246          NaN          NaN        NaN     NaN
# 1250          NaN          NaN        NaN     NaN
# 1251          NaN          NaN        NaN     NaN
# 1252          NaN          NaN        NaN     NaN
# 1253          NaN          NaN        NaN     NaN
#
# [584 rows x 38 columns]

# %% [markdown]
# # Two specific examples

# %%
print(matching_player_data.loc[1, ['Player', 'year', 'Rec', 'Yds', 'TD', 'position']])  # Row 2
print(matching_player_data.loc[13, ['Player', 'year', 'Rec', 'Yds', 'TD', 'position']])  # Row 14
# Out:
# Player      Calvin Johnson
# year                  2008
# Rec                   78.0
# Yds                 1331.0
# TD                    12.0
# position                WR
# Name: 1, dtype: object
# Player      Calvin Johnson
# year                  2008
# Rec                   78.0
# Yds                 1331.0
# TD                    12.0
# position                TE
# Name: 13, dtype: object

# %% [markdown]
# So, you can clearly see the identical statistics listed for two different positions.

# %% [markdown]
# # Keep only the WR or TE rows for players depending on their position listed in the Hall of Fame CSV

# %%
# Loop over each player in 'hof_df'
for index, row in hof_df.iterrows():
    player = row['player']
    position = row['position']

    # Filter out 'WR' or 'TE' rows based on the position in 'hof_df'
    if position == 'WR':
        # Keep WR rows and remove TE rows for this player in 'matching_player_data'
        matching_player_data = matching_player_data[(matching_player_data['Player'] != player) | (matching_player_data['position'] == 'WR')]
    elif position == 'TE':
        # Keep TE rows and remove WR rows for this player in 'matching_player_data'
        matching_player_data = matching_player_data[(matching_player_data['Player'] != player) | (matching_player_data['position'] == 'TE')]

# Check the resulting dataframe
print(matching_player_data)
# Out:
#               Player   Rec     Yds    TD   20+   40+   LNG  Rec 1st  1st%  \
# 0     Calvin Johnson  48.0   756.0   4.0  12.0   1.0  49.0     38.0  79.2
# 1     Calvin Johnson  78.0  1331.0  12.0  21.0   7.0  96.0     52.0  66.7
# 2     Calvin Johnson  67.0   984.0   5.0  15.0   4.0  75.0     46.0  68.7
# 3     Calvin Johnson  77.0  1120.0  12.0  16.0   3.0  87.0     57.0  74.0
# 4     Calvin Johnson  96.0  1681.0  16.0  32.0  10.0  73.0     77.0  80.2
# ...              ...   ...     ...   ...   ...   ...   ...      ...   ...
# 1264  Eric Dickerson   NaN     NaN  18.0  11.0   3.0   NaN      NaN   NaN
# 1265  Eric Dickerson   NaN     NaN  14.0  18.0   4.0   NaN      NaN   NaN
# 1266  Eric Dickerson   NaN     NaN  12.0   4.0   2.0   NaN      NaN   NaN
# 1267  Eric Dickerson   NaN     NaN  11.0  10.0   2.0   NaN      NaN   NaN
# 1268  Eric Dickerson   NaN     NaN   6.0   7.0   2.0   NaN      NaN   NaN
#
#       Rec FUM  ...  Rush FUM  FGM FG %  1-19 > A-M  20-29 > A-M  30-39 > A-M  \
# 0         1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 1         2.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 2         3.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 3         1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# 4         1.0  ...       NaN  NaN  NaN         NaN          NaN          NaN
# ...       ...  ...       ...  ...  ...         ...          ...          ...
# 1264      NaN  ...      12.0  NaN  NaN         NaN          NaN          NaN
# 1265      NaN  ...      13.0  NaN  NaN         NaN          NaN          NaN
# 1266      NaN  ...      10.0  NaN  NaN         NaN          NaN          NaN
# 1267      NaN  ...      11.0  NaN  NaN         NaN          NaN          NaN
# 1268      NaN  ...       7.0  NaN  NaN         NaN          NaN          NaN
#
#       40-49 > A-M  50-59 > A-M  60+ > A-M  FG Blk
# 0             NaN          NaN        NaN     NaN
# 1             NaN          NaN        NaN     NaN
# 2             NaN          NaN        NaN     NaN
# 3             NaN          NaN        NaN     NaN
# 4             NaN          NaN        NaN     NaN
# ...           ...          ...        ...     ...
# 1264          NaN          NaN        NaN     NaN
# 1265          NaN          NaN        NaN     NaN
# 1266          NaN          NaN        NaN     NaN
# 1267          NaN          NaN        NaN     NaN
# 1268          NaN          NaN        NaN     NaN
#
# [961 rows x 38 columns]

# %% [markdown]
# # Replace Headers
# This scraped dataframe uses camelCase for the headers. My other two datasets I've been working with during this project use snake_case, so let's change the camelCase to snake_case to be consistent with the other datasets.

# %%
# Define the mapping of old column names to snake_case
column_mapping = {
    "Player": "player",
    "Rec": "rec",
    "Yds": "yards",
    "TD": "td",
    "20+": "rec_20_plus",
    "40+": "rec_40_plus",
    "LNG": "long",
    "Rec 1st": "rec_1st",
    "1st%": "rec_1st_pct",
    "Rec FUM": "rec_fum",
    "Rec YAC/R": "rec_yac",
    "Tgts": "targts",
    "position": "position",
    "year": "year",
    "Pass Yds": "pass_yds",
    "Yds/Att": "yds_per_att",
    "Att": "att",
    "Cmp": "cmp",
    "Cmp %": "cmp_pct",
    "INT": "int",
    "Rate": "rate",
    "1st": "pass_1st",
    "Lng": "pass_long",
    "Sck": "sacks",
    "SckY": "sack_yards",
    "Rush Yds": "rush_yds",
    "Rush 1st": "rush_1st",
    "Rush 1st%": "rush_1st_pct",
    "Rush FUM": "rush_fum",
    "FGM": "fgm",
    "FG %": "fg_pct",
    "1-19 > A-M": "fg_1_19",
    "20-29 > A-M": "fg_20_29",
    "30-39 > A-M": "fg_30_39",
    "40-49 > A-M": "fg_40_49",
    "50-59 > A-M": "fg_50_59",
    "60+ > A-M": "fg_60_plus",
    "FG Blk": "fg_blk"
}

# Rename the columns in the DataFrame
matching_player_data.rename(columns=column_mapping, inplace=True)

# Display the updated column names
print(matching_player_data.head())  # Verify the changes
# Out:
#            player   rec   yards    td  rec_20_plus  rec_40_plus  long  \
# 0  Calvin Johnson  48.0   756.0   4.0         12.0          1.0  49.0
# 1  Calvin Johnson  78.0  1331.0  12.0         21.0          7.0  96.0
# 2  Calvin Johnson  67.0   984.0   5.0         15.0          4.0  75.0
# 3  Calvin Johnson  77.0  1120.0  12.0         16.0          3.0  87.0
# 4  Calvin Johnson  96.0  1681.0  16.0         32.0         10.0  73.0
#
#    rec_1st  rec_1st_pct  rec_fum  ...  rush_fum  fgm fg_pct  fg_1_19  \
# 0     38.0         79.2      1.0  ...       NaN  NaN    NaN      NaN
# 1     52.0         66.7      2.0  ...       NaN  NaN    NaN      NaN
# 2     46.0         68.7      3.0  ...       NaN  NaN    NaN      NaN
# 3     57.0         74.0      1.0  ...       NaN  NaN    NaN      NaN
# 4     77.0         80.2      1.0  ...       NaN  NaN    NaN      NaN
#
#    fg_20_29  fg_30_39  fg_40_49  fg_50_59  fg_60_plus  fg_blk
# 0       NaN       NaN       NaN       NaN         NaN     NaN
# 1       NaN       NaN       NaN       NaN         NaN     NaN
# 2       NaN       NaN       NaN       NaN         NaN     NaN
# 3       NaN       NaN       NaN       NaN         NaN     NaN
# 4       NaN       NaN       NaN       NaN         NaN     NaN
#
# [5 rows x 38 columns]

# %%
scraped_data = pd.read_csv(r"C:\Users\Weekseey\Documents\Bellevue Work\Data Wrangling\cleaned_matching_player_data.csv")

# %%
print(scraped_data)
# Out:
#           player   rec   yards    td  rec_20_plus  rec_40_plus  long  rec_1st  \
# 0     Andre Reed  48.0   637.0   4.0         10.0          0.0  32.0     31.0
# 1     Andre Reed  53.0   739.0   7.0         11.0          1.0  55.0     38.0
# 2     Andre Reed  57.0   752.0   5.0         10.0          1.0  40.0     38.0
# 3     Andre Reed  71.0   968.0   6.0         16.0          2.0  65.0     40.0
# 4     Andre Reed  88.0  1312.0   9.0         18.0          5.0  78.0     62.0
# ..           ...   ...     ...   ...          ...          ...   ...      ...
# 513  Warren Moon   NaN     NaN   7.0         19.0          2.0   NaN      NaN
# 514  Warren Moon   NaN     NaN  25.0         52.0          9.0   NaN      NaN
# 515  Warren Moon   NaN     NaN  11.0         22.0          3.0   NaN      NaN
# 516  Warren Moon   NaN     NaN   0.0          1.0          0.0   NaN      NaN
# 517  Warren Moon   NaN     NaN   1.0          3.0          1.0   NaN      NaN
#
#      rec_1st_pct  rec_fum  ...  rush_fum  fgm fg_pct  fg_1_19  fg_20_29  \
# 0           64.6      0.0  ...       NaN  NaN    NaN      NaN       NaN
# 1           71.7      1.0  ...       NaN  NaN    NaN      NaN       NaN
# 2           66.7      0.0  ...       NaN  NaN    NaN      NaN       NaN
# 3           56.3      1.0  ...       NaN  NaN    NaN      NaN       NaN
# 4           70.4      4.0  ...       NaN  NaN    NaN      NaN       NaN
# ..           ...      ...  ...       ...  ...    ...      ...       ...
# 513         30.0      NaN  ...       NaN  NaN    NaN      NaN       NaN
# 514         33.9      NaN  ...       NaN  NaN    NaN      NaN       NaN
# 515         30.6      NaN  ...       NaN  NaN    NaN      NaN       NaN
# 516         33.3      NaN  ...       NaN  NaN    NaN      NaN       NaN
# 517         26.5      NaN  ...       NaN  NaN    NaN      NaN       NaN
#
#      fg_30_39  fg_40_49  fg_50_59  fg_60_plus  fg_blk
# 0         NaN       NaN       NaN         NaN     NaN
# 1         NaN       NaN       NaN         NaN     NaN
# 2         NaN       NaN       NaN         NaN     NaN
# 3         NaN       NaN       NaN         NaN     NaN
# 4         NaN       NaN       NaN         NaN     NaN
# ..        ...       ...       ...         ...     ...
# 513       NaN       NaN       NaN         NaN     NaN
# 514       NaN       NaN       NaN         NaN     NaN
# 515       NaN       NaN       NaN         NaN     NaN
# 516       NaN       NaN       NaN         NaN     NaN
# 517       NaN       NaN       NaN         NaN     NaN
#
# [518 rows x 38 columns]

# %% [markdown]
# # Rearrange columns so the first 3 are player, position, and year

# %% [markdown]
# I think this gives the dataset better readability.

# %%
# Reorder columns so that 'player', 'position', 'year' are first
cols = ['player', 'position', 'year'] + [col for col in scraped_data.columns if col not in ['player', 'position', 'year']]
scraped_data = scraped_data[cols]

# %%
print(scraped_data)
# Out:
#           player position  year   rec   yards    td  rec_20_plus  rec_40_plus  \
# 0     Andre Reed       WR  1985  48.0   637.0   4.0         10.0          0.0
# 1     Andre Reed       WR  1986  53.0   739.0   7.0         11.0          1.0
# 2     Andre Reed       WR  1987  57.0   752.0   5.0         10.0          1.0
# 3     Andre Reed       WR  1988  71.0   968.0   6.0         16.0          2.0
# 4     Andre Reed       WR  1989  88.0  1312.0   9.0         18.0          5.0
# ..           ...      ...   ...   ...     ...   ...          ...          ...
# 513  Warren Moon       QB  1996   NaN     NaN   7.0         19.0          2.0
# 514  Warren Moon       QB  1997   NaN     NaN  25.0         52.0          9.0
# 515  Warren Moon       QB  1998   NaN     NaN  11.0         22.0          3.0
# 516  Warren Moon       QB  1999   NaN     NaN   0.0          1.0          0.0
# 517  Warren Moon       QB  2000   NaN     NaN   1.0          3.0          1.0
#
#      long  rec_1st  ...  rush_fum  fgm  fg_pct  fg_1_19  fg_20_29  fg_30_39  \
# 0    32.0     31.0  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 1    55.0     38.0  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 2    40.0     38.0  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 3    65.0     40.0  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 4    78.0     62.0  ...       NaN  NaN     NaN      NaN       NaN       NaN
# ..    ...      ...  ...       ...  ...     ...      ...       ...       ...
# 513   NaN      NaN  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 514   NaN      NaN  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 515   NaN      NaN  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 516   NaN      NaN  ...       NaN  NaN     NaN      NaN       NaN       NaN
# 517   NaN      NaN  ...       NaN  NaN     NaN      NaN       NaN       NaN
#
#      fg_40_49  fg_50_59  fg_60_plus  fg_blk
# 0         NaN       NaN         NaN     NaN
# 1         NaN       NaN         NaN     NaN
# 2         NaN       NaN         NaN     NaN
# 3         NaN       NaN         NaN     NaN
# 4         NaN       NaN         NaN     NaN
# ..        ...       ...         ...     ...
# 513       NaN       NaN         NaN     NaN
# 514       NaN       NaN         NaN     NaN
# 515       NaN       NaN         NaN     NaN
# 516       NaN       NaN         NaN     NaN
# 517       NaN       NaN         NaN     NaN
#
# [518 rows x 38 columns]

# %% [markdown]
# # Data Transformations Performed:
# 1. **Removed Duplicates:** Identified and removed duplicate rows to ensure unique entries across the dataset.
#
# 2. **Data Type Fixing:** Addressed inconsistencies in data types, particularly for columns related to field goal statistics, ensuring proper formats for analysis.
#
# 3. **Duplicate Statistical Entries:** Eliminated redundant statistics for players listed under multiple positions (e.g., WR & TE) where the stats were identical, retaining the correct position as per the Hall of Fame data.
#
# 4. **Standardized Column Headers:** Replaced column headers with snake_case formatting for consistency across datasets and improved readability.
#
# 5. **Rearranged Columns:** Adjusted the column order to enhance the logical flow, with key columns like player, position, and year positioned at the beginning for better accessibility and clarity.
